// %%
%use dataframe
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>

// %%
// This file contains LastFM scrobble data
// from: Saturday, January 1, 2022 12:00:00 AM
// until: Wednesday, November 29, 2023 9:17:54 PM
val df = DataFrame.read("scrobbles-zubie7a-1701292674.csv")

// %%
df.head(5)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321536"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 5, columnsCount = 8</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"uts: Int\">uts</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">1701292674</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1701292540</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1701292319</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1701291802</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1701291660</span></span>"] },
// { name: "<span title=\"utc_time: String\">utc_time</span>", children: [], rightAlign: false, values: ["29 Nov 2023, 21:17","29 Nov 2023, 21:15","29 Nov 2023, 21:11","29 Nov 2023, 21:03","29 Nov 2023, 21:01"] },
// { name: "<span title=\"artist: String\">artist</span>", children: [], rightAlign: false, values: ["Masayoshi Takanaka","Nat King Cole","INXS","Led Zeppelin","Mariachi Entertainment System"] },
// { name: "<span title=\"artist_mbid: String?\">artist_mbid</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","fbe054ec-a143-4101-9e9e-64abc5ff5ac9","481bf5f9-2e7c-4c44-b08a-05b32bc7c00d","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","de66e21f-fa53-4b98-b37d-e2db8b5422c0"] },
// { name: "<span title=\"album: String\">album</span>", children: [], rightAlign: false, values: ["&#34425;&#20253;&#35500;~THE RAINBOW GOBLINS~","A Mis Amigos","Kick (Remastered 2011)","Physical Graffiti (Deluxe Edition)","Mariachi Entertainment System"] },
// { name: "<span title=\"album_mbid: String?\">album_mbid</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","61a9b9a3-84cf-403f-9b91-cdb1e3d80f45","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","11064a13-6263-46ba-ac58-09542b9f0bd4"] },
// { name: "<span title=\"track: String\">track</span>", children: [], rightAlign: false, values: ["You Can Never Come To This Place","Aquellos Ojos Verdes","New Sensation","Kashmir - Remaster","<span class=\"formatted\" title=\"Bloody Tears (from &#34;Castlevania II: Simon&#39;s Quest&#34;)\">Bloody Tears (from &#34;Castlevania II: S<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"track_mbid: String?\">track_mbid</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","<span class=\"formatted\" title=\"\"><span class=\"null\">null</span></span>","789adb6b-0bb6-40e5-9e0d-351b25dd5426"] },
// ], id: -352321536, rootId: -352321536, totalRows: 5 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-352321536) });
//
//
//         </script>
//         </html>

// %%
// Boundary epoch values for time range
// 1640995200: Saturday, January 1, 2022 12:00:00 AM
// 1668165071: November 11, 2022 11:11:11 AM
// 1640995200: January 1, 2023 00:00:00 AM
// 1699701071: Saturday, November 11, 2023 11:11:11 AM
val start2022 = 1640995200
val end2022 = 1668165071
val start2023 = 1672531200
val end2023 = 1699701071
// Create "wrapped" dataframes between January 1 and November 11th,
// trying to mimic Spotify's time range (sorry December!)
val dfWrapped2022 = df.filter { start2022 < uts && uts < end2022 }
val dfWrapped2023 = df.filter { start2023 < uts && uts < end2023 }

// %%
// Find the 10 most listened songs in 2022 and 2023, to compare.

val dfMostListenedSongs2022 = 
    dfWrapped2022
        .groupBy("track")
        .count()
        .rename("track").into("track2022")
        .rename("count").into("countYear2022")
        .sortByDesc("countYear2022")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")


val dfMostListenedSongs2023 = 
    dfWrapped2023
        .groupBy("track")
        .count()
        .rename("track").into("track2023")
        .rename("count").into("countYear2023")
        .sortByDesc("countYear2023")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")

// %%
val dfRanksSongs2022 = 
    dfMostListenedSongs2022
        .select { rank and track2022 }
        .rename("rank").into { "track2023_rank2022" }
        .rename("track2022").into { "track" }

// %%
// With the left join, tracks from 2023 not present in 2022 will have
// the 2022 values filled in with null.
val dfMostListenedSongs2023WithPreviousYearRank =
    dfMostListenedSongs2023.leftJoin(dfRanksSongs2022) { track2023 match right.track }

dfMostListenedSongs2022
    .join(
        dfMostListenedSongs2023WithPreviousYearRank
            .add("track2023_rank2023") { rank } 
    )
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321535"></table>
//
// <p class="dataframe_description">... showing only top 20 of 6771 rows</p><p class="dataframe_description">DataFrame: rowsCount = 6771, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">19</span></span>"] },
// { name: "<span title=\"track2022: String\">track2022</span>", children: [], rightAlign: false, values: ["This Is a Life","Visions of a Life","Heroes And Villains - Remastered 2001","You Without End","Blue Sands","Daydream In Blue","Buddy Holly","Starlight","15 Step","We Don&#39;t Talk About Bruno","Surface Pressure","Everlong","Kill Or Be Killed","Where Is My Mind? - Remastered","Gayane: Gayane&#39;s Adagio","You! Me! Dancing!","Meu Refrigerador N&#227;o Funciona","Knights of Cydonia","The Rumbling","Welcome to the Black Parade"] },
// { name: "<span title=\"countYear2022: Int\">countYear2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">117</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">84</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">70</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">69</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">65</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">62</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">57</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">55</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">54</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">53</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">51</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">49</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">45</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">44</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">43</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">43</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">43</span></span>"] },
// { name: "<span title=\"track2023: String\">track2023</span>", children: [], rightAlign: false, values: ["Summertime","Under the Light","Crazy on You","Visions of a Life","Everlong","Creep - Acoustic","Ommadawn Pt.1 - 2010 Mix","I&#39;m Always Chasing Rainbows","<span class=\"formatted\" title=\"The Plan - From the Motion Picture &#34;TENET&#34;\">The Plan - From the Motion Picture &#34;T<span class=\"structural\">...</span></span>","Forest","The Mysterious Vanishing of Electra","Aerodynamic","Bubulina"

// %%
// Find the 10 most listened albums in 2022 and 2023, to compare.

val dfMostListenedAlbums2022 = 
    dfWrapped2022
        .groupBy("album")
        .count()
        .rename("album").into("album2022")
        .rename("count").into("countYear2022")
        .sortByDesc("countYear2022")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")
        
val dfMostListenedAlbums2023 = 
    dfWrapped2023
        .groupBy("album")
        .count()
        .rename("album").into("album2023")
        .rename("count").into("countYear2023")
        .sortByDesc("countYear2023")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")

// %%
val dfRanksAlbums2022 = 
    dfMostListenedAlbums2022
        .select { rank and album2022 }
        .rename("rank").into { "album2023_rank2022" }
        .rename("album2022").into { "album" }

// %%
// With the left join, albums from 2023 not present in 2022 will have
// the 2022 values filled in with null.
val dfMostListenedAlbums2023WithPreviousYearRank =
    dfMostListenedAlbums2023.leftJoin(dfRanksAlbums2022) { album2023 match right.album }

dfMostListenedAlbums2022
    .join(
        dfMostListenedAlbums2023WithPreviousYearRank
            .add("album2023_rank2023") { rank } 
    )
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321534"></table>
//
// <p class="dataframe_description">... showing only top 20 of 4355 rows</p><p class="dataframe_description">DataFrame: rowsCount = 4355, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">19</span></span>"] },
// { name: "<span title=\"album2022: String\">album2022</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Shiro SAGISU Music from &#34;SHIN EVANGELION&#34; EVANGELION: 3.0+1.0.\">Shiro SAGISU Music from &#34;SHIN EVANGEL<span class=\"structural\">...</span></span>","Will Of The People","Un Verano Sin Ti","Visions of a Life","<span class=\"formatted\" title=\"Everything Everywhere All at Once (Original Motion Picture Soundtrack)\">Everything Everywhere All at Once (Or<span class=\"structural\">...</span></span>","Black Holes and Revelations","Under Cover","Work From Home With Minimalism","Hawaii: Part II","The Black Parade","Across the Universe","<span class=\"formatted\" title=\"La La Land (Original Motion Picture Soundtrack)\">La La Land (Original Motion Picture S<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Encanto (Original Motion Picture Soundtrack)\">Encanto (Original Motion Picture Soun<span class=\"structural\">...</span></span>","Raconto","Three Cheers for Sweet Revenge","<span class=\"formatted\" title=\"This Is A Life (From the Original Motion Picture &#34;Everything Everywhere All at Once&#34;)\">This Is A Life (From the Original Mot<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"The Batman (Original Motion Picture Soundtrack)\">The Batman (Original Motion Picture S<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Parallel Mothers (Original Motion Picture Soundtrack)\">Parallel Mothers (Original Motion Pic<span class=\"structural\">...</span></span>","Random Access Memories","Discovery"] },
// { name: "<span title=\"countYear2022: Int\">countYear2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">354</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">232</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">215</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">193</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">163</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">162</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">158</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">157</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">148</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">138</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">126</span></span>","<span class=\"format

// %%
// Find the 10 most listened artists in 2022 and 2023, to compare.

val dfMostListenedArtists2022 = 
    dfWrapped2022
        .groupBy("artist")
        .count()
        .rename("artist").into("artist2022")
        .rename("count").into("countYear2022")
        .sortByDesc("countYear2022")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")

val dfMostListenedArtists2023 = 
    dfWrapped2023
        .groupBy("artist")
        .count()
        .rename("artist").into("artist2023")
        .rename("count").into("countYear2023")
        .sortByDesc("countYear2023")
        // Adds an increasing iterator per row, to be used as rank.
        .addId("rank")

// %%
val dfRanksArtists2022 = 
    dfMostListenedArtists2022
        .select { rank and artist2022 }
        .rename("rank").into { "artist2023_rank2022" }
        .rename("artist2022").into { "artist" }

// %%
// With the left join, albums from 2023 not present in 2022 will have
// the 2022 values filled in with null.
val dfMostListenedArtists2023WithPreviousYearRank =
    dfMostListenedArtists2023.leftJoin(dfRanksArtists2022) { artist2023 match right.artist }

dfMostListenedArtists2022
    .join(
        dfMostListenedArtists2023WithPreviousYearRank
            .add("artist2023_rank2023") { rank } 
    )
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321533"></table>
//
// <p class="dataframe_description">... showing only top 20 of 2844 rows</p><p class="dataframe_description">DataFrame: rowsCount = 2844, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">11</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">14</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">19</span></span>"] },
// { name: "<span title=\"artist2022: String\">artist2022</span>", children: [], rightAlign: false, values: ["Muse","My Chemical Romance","Scott Bradlee&#39;s Postmodern Jukebox","Shiro Sagisu","Philip Glass","Son Lux","Daft Punk","Pink Floyd","Queen","Bad Bunny","Nobuo Uematsu","Weezer","Gustavo Santaolalla","Fleet Foxes","Wolf Alice","Tangerine Dream","&#26893;&#26494;&#20280;&#22827;","Arcade Fire","The Beatles","Miracle Musical"] },
// { name: "<span title=\"countYear2022: Int\">countYear2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">999</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">425</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">382</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">374</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">328</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">313</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">265</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">242</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">230</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">217</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">216</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">206</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">204</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">180</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">167</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">163</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">161</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">158</span></span>"] },
// { name: "<span title=\"artist2023: String\">artist2023</span>", children: [], rightAlign: false, values: ["Muse","ABBA","Philip Glass","Daft Punk","Hans Zimmer","Pink Floyd","Shiro Sagisu","My Chemical Romance","Mac Quayle","Trent Reznor and Atticus Ross","Scott Bradlee&#39;s Postmodern Jukebox","Led Zeppelin","Radiohead","Fleet Foxes","&#26893;&#26494;&#20280;&#22827;","Queen","Fleece","La M&#225;quina de Hacer P&#225;jaros","Foo Fighters","The Beach Boys"] },
// { name: "<span title=\"countYear2023: Int\">countYear2023</span>", children: [], rightAlign: true, values: ["<span class=\

// %%
// Add columns for timestamps and date.
import java.sql.Timestamp

val dfWrappedWithDate2022 = 
    dfWrapped2022
        .add("timestamp") { Timestamp("uts"<Long>() * 1000 ) } 
        .add("date") { "timestamp"<Timestamp>().toString().substring(0..10) }

val dfWrappedWithDate2023 = 
    dfWrapped2023
        .add("timestamp") { Timestamp("uts"<Long>() * 1000 ) } 
        .add("date") { "timestamp"<Timestamp>().toString().substring(0..10) }

// %%
// Find the 10 days with the most songs listened in 2022 and 2023, to compare.

val dfDaysWithMostSongs2022 = 
    dfWrappedWithDate2022
        .groupBy("date")
        .count()
        .rename("date").into("day2022")
        .rename("count").into("countDay2022")
        .sortByDesc("countDay2022")
        .head(10)
        .addId("rank")

val dfDaysWithMostSongs2023 = 
    dfWrappedWithDate2023
        .groupBy("date")
        .count()
        .rename("date").into("day2023")
        .rename("count").into("countDay2023")
        .sortByDesc("countDay2023")
        .head(10)
        .addId("rank")

dfDaysWithMostSongs2022.join(dfDaysWithMostSongs2023)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321532"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 10, columnsCount = 5</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>"] },
// { name: "<span title=\"day2022: String\">day2022</span>", children: [], rightAlign: false, values: ["2022-04-07 ","2022-01-31 ","2022-01-28 ","2022-01-30 ","2022-03-24 ","2022-04-29 ","2022-07-15 ","2022-08-24 ","2022-08-02 ","2022-03-15 "] },
// { name: "<span title=\"countDay2022: Int\">countDay2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">267</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">238</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">235</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">230</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">227</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">225</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">224</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">223</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">220</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">220</span></span>"] },
// { name: "<span title=\"day2023: String\">day2023</span>", children: [], rightAlign: false, values: ["2023-10-06 ","2023-09-09 ","2023-06-28 ","2023-11-07 ","2023-07-15 ","2023-11-08 ","2023-08-10 ","2023-10-02 ","2023-09-08 ","2023-10-21 "] },
// { name: "<span title=\"countDay2023: Int\">countDay2023</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">350</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">309</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">244</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">239</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">223</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">222</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">221</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">200</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">180</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">175</span></span>"] },
// ], id: -352321532, rootId: -352321532, totalRows: 10 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-352321532) });
//
//
//         </script>
//         </html>

// %%
// Find the 10 songs most listened the same day in 2022 and 2023, to compare.

val dfSongsMostRepeatedInADay2022 = 
    dfWrappedWithDate2022
        .groupBy{ "track" and "date" }
        .count()
        .rename("date").into("day2022")
        .rename("track").into("track2022")
        .rename("count").into("countDay2022")
        .sortByDesc("countDay2022")
        .head(10)
        .addId("rank")

val dfSongsMostRepeatedInADay2023 = 
    dfWrappedWithDate2023
        .groupBy{ "track" and "date" }
        .count()
        .rename("date").into("day2023")
        .rename("track").into("track2023")
        .rename("count").into("countDay2023")
        .sortByDesc("countDay2023")
        .head(10)
        .addId("rank")

dfSongsMostRepeatedInADay2022.join(dfSongsMostRepeatedInADay2023)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321531"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 10, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>"] },
// { name: "<span title=\"track2022: String\">track2022</span>", children: [], rightAlign: false, values: ["This Is a Life","Meu Refrigerador N&#227;o Funciona","Gayane: Gayane&#39;s Adagio","Love Theme - db tango","Brand New City","Kill Or Be Killed","Heroes And Villains - Remastered 2001","The Rumbling","You Without End","Visions of a Life"] },
// { name: "<span title=\"day2022: String\">day2022</span>", children: [], rightAlign: false, values: ["2022-04-29 ","2022-06-23 ","2022-02-26 ","2022-10-23 ","2022-05-24 ","2022-07-25 ","2022-04-14 ","2022-04-27 ","2022-06-21 ","2022-06-21 "] },
// { name: "<span title=\"countDay2022: Int\">countDay2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">114</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">22</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">21</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">20</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">19</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">18</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">17</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">16</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">15</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">13</span></span>"] },
// { name: "<span title=\"track2023: String\">track2023</span>", children: [], rightAlign: false, values: ["Forest","<span class=\"formatted\" title=\"The Plan - From the Motion Picture &#34;TENET&#34;\">The Plan - From the Motion Picture &#34;T<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Ultimecia&#39;s Castle (From &#34;Final Fantasy VIII&#34;)\">Ultimecia&#39;s Castle (From &#34;Final Fanta<span class=\"structural\">...</span></span>","Stella Maris","Ruled by Secrecy","Mamma Mia","The Name of the Game","The Winner Takes It All","Thank You for the Music","Dancing Queen"] },
// { name: "<span title=\"day2023: String\">day2023</span>", children: [], rightAlign: false, values: ["2023-04-12 ","2023-05-24 ","2023-06-06 ","2023-03-01 ","2023-06-14 ","2023-08-04 ","2023-08-04 ","2023-08-04 ","2023-08-04 ","2023-08-04 "] },
// { name: "<span title=\"countDay2023: Int\">countDay2023</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">13</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">12</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">10</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>"] },
// ], id: -352321531, rootId: -352321531, totalRows: 10 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-352321531) });
//
//
//         </script>
//         </html>

// %%
// Find the 10 albums most listened the same day in 2022 and 2023, to compare.

val dfAlbumsMostListenedInADay2022 = 
    dfWrappedWithDate2022
        .groupBy{ "album" and "date" }
        .count()
        .rename("date").into("day2022")
        .rename("album").into("album2022")
        .rename("count").into("countDay2022")
        .sortByDesc("countDay2022")
        .head(10)
        .addId("rank")

val dfAlbumsMostListenedInADay2023 = 
    dfWrappedWithDate2023
        .groupBy{ "album" and "date" }
        .count()
        .rename("date").into("day2023")
        .rename("album").into("album2023")
        .rename("count").into("countDay2023")
        .sortByDesc("countDay2023")
        .head(10)
        .addId("rank")

dfAlbumsMostListenedInADay2022.join(dfAlbumsMostListenedInADay2023)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321530"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 10, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>"] },
// { name: "<span title=\"album2022: String\">album2022</span>", children: [], rightAlign: false, values: ["<span class=\"formatted\" title=\"Shiro SAGISU Music from &#34;SHIN EVANGELION&#34; EVANGELION: 3.0+1.0.\">Shiro SAGISU Music from &#34;SHIN EVANGEL<span class=\"structural\">...</span></span>","Un Verano Sin Ti","<span class=\"formatted\" title=\"This Is A Life (From the Original Motion Picture &#34;Everything Everywhere All at Once&#34;)\">This Is A Life (From the Original Mot<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Everything Everywhere All at Once (Original Motion Picture Soundtrack)\">Everything Everywhere All at Once (Or<span class=\"structural\">...</span></span>","Will Of The People","Visions of a Life","<span class=\"formatted\" title=\"Shiro SAGISU Music from &#34;SHIN EVANGELION&#34; EVANGELION: 3.0+1.0.\">Shiro SAGISU Music from &#34;SHIN EVANGEL<span class=\"structural\">...</span></span>","<span class=\"formatted\" title=\"Distant Worlds and a New World Collections: Music from Final Fantasy VII\">Distant Worlds and a New World Collec<span class=\"structural\">...</span></span>","The Dark Side of the Moon","<span class=\"formatted\" title=\"&#34;A Divina Com&#233;dia Ou Ando Meio Desligado&#34;\">&#34;A Divina Com&#233;dia Ou Ando Meio Deslig<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"day2022: String\">day2022</span>", children: [], rightAlign: false, values: ["2022-03-24 ","2022-05-17 ","2022-04-29 ","2022-04-29 ","2022-08-27 ","2022-08-05 ","2022-11-01 ","2022-07-13 ","2022-04-04 ","2022-06-23 "] },
// { name: "<span title=\"countDay2022: Int\">countDay2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">167</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">165</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">111</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">108</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">103</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">86</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">78</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">67</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">53</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">51</span></span>"] },
// { name: "<span title=\"album2023: String\">album2023</span>", children: [], rightAlign: false, values: ["ABBA Gold","<span class=\"formatted\" title=\"Mr. Robot, Vol. 8 (Original Television Series Soundtrack)\">Mr. Robot, Vol. 8 (Original Televisio<span class=\"structural\">...</span></span>","ABBA Gold","<span class=\"formatted\" title=\"Interstellar (Original Motion Picture Soundtrack) [Expanded Edition]\">Interstellar (Original Motion Picture<span class=\"structural\">...</span></span>","Classic Rock Renaissance","Simulation Theory (Super Deluxe)","The Great Final Fantasy Medley","The Resistance","Work From Home With Minimalism","<span class=\"formatted\" title=\"Shiro SAGISU Music from &#34;SHIN EVANGELION&#34; EVANGELION: 3.0+1.0.\">Shiro SAGISU Music from &#34;SHIN EVANGEL<span class=\"structural\">...</span></span>"] },
// { name: "<span title=\"day2023: String\">day2023</span>", children: [], rightAlign: false, values: ["2023-08-04 ","2023-05-09 ","2023-08-09 ","2023-06-07 ","2023-04-06 ","2023-03-15 ","2023-03-11 ","2023-03-15 ","2023-10-02 ","2023-06-13 "] },
// { name: "<span title=

// %%
// Find the 10 artists most listened the same day in 2022 and 2023, to compare.

val dfArtistsMostListenedInADay2022 = 
    dfWrappedWithDate2022
        .groupBy{ "artist" and "date" }
        .count()
        .rename("date").into("day2022")
        .rename("artist").into("artist2022")
        .rename("count").into("countDay2022")
        .sortByDesc("countDay2022")
        .head(10)
        .addId("rank")

val dfArtistsMostListenedInADay2023 = 
    dfWrappedWithDate2023
        .groupBy{ "artist" and "date" }
        .count()
        .rename("date").into("day2023")
        .rename("artist").into("artist2023")
        .rename("count").into("countDay2023")
        .sortByDesc("countDay2023")
        .head(10)
        .addId("rank")

dfArtistsMostListenedInADay2022.join(dfArtistsMostListenedInADay2023)
// Out:
//         <html>
//         <head>
//             <style type="text/css">
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//
//
//             </style>
//         </head>
//         <body>
//
// <table class="dataframe" id="df_-352321529"></table>
//
// <p class="dataframe_description">DataFrame: rowsCount = 10, columnsCount = 7</p>
//         </body>
//         <script>
//
// /*<!--*/
// call_DataFrame(function() { DataFrame.addTable({ cols: [{ name: "<span title=\"rank: Int\">rank</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">0</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">1</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">2</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">3</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">4</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">5</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">6</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">7</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">8</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">9</span></span>"] },
// { name: "<span title=\"artist2022: String\">artist2022</span>", children: [], rightAlign: false, values: ["Son Lux","Shiro Sagisu","Bad Bunny","Arcade Fire","Muse","Wolf Alice","Muse","Shiro Sagisu","Tally Hall","&#26893;&#26494;&#20280;&#22827;"] },
// { name: "<span title=\"day2022: String\">day2022</span>", children: [], rightAlign: false, values: ["2022-04-29 ","2022-03-24 ","2022-05-17 ","2022-04-28 ","2022-08-27 ","2022-08-05 ","2022-02-07 ","2022-11-01 ","2022-07-01 ","2022-07-13 "] },
// { name: "<span title=\"countDay2022: Int\">countDay2022</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">225</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">167</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">165</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">125</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">106</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">86</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">86</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">78</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">69</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">64</span></span>"] },
// { name: "<span title=\"artist2023: String\">artist2023</span>", children: [], rightAlign: false, values: ["ABBA","Muse","Muse","Mac Quayle","ABBA","Muse","Muse","Fleet Foxes","Hans Zimmer","&#26893;&#26494;&#20280;&#22827;"] },
// { name: "<span title=\"day2023: String\">day2023</span>", children: [], rightAlign: false, values: ["2023-08-04 ","2023-03-15 ","2023-08-28 ","2023-05-09 ","2023-08-09 ","2023-08-29 ","2023-07-08 ","2023-08-27 ","2023-06-07 ","2023-11-08 "] },
// { name: "<span title=\"countDay2023: Int\">countDay2023</span>", children: [], rightAlign: true, values: ["<span class=\"formatted\" title=\"\"><span class=\"numbers\">113</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">89</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">61</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">56</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">51</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">50</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">48</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">43</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">37</span></span>","<span class=\"formatted\" title=\"\"><span class=\"numbers\">35</span></span>"] },
// ], id: -352321529, rootId: -352321529, totalRows: 10 } ) });
// /*-->*/
//
// call_DataFrame(function() { DataFrame.renderTable(-352321529) });
//
//
//         </script>
//         </html>

// %%
val countUniqueSongs2022 = (
    dfWrappedWithDate2022.groupBy("track").count()
).count().toFloat()

// %%
val countUniqueSongs2023 = (
    dfWrappedWithDate2023.groupBy("track").count()
).count().toFloat()

// %%
countUniqueSongs2022
// Out:
// 7248.0

// %%
countUniqueSongs2023
// Out:
// 6771.0

// %%
countUniqueSongs2023 / countUniqueSongs2022
// Out:
// 0.9341887

// %%
val countUniqueArtists2022 = (
    dfWrappedWithDate2022.groupBy("artist").count()
).count().toFloat()

// %%
val countUniqueArtists2023 = (
    dfWrappedWithDate2023.groupBy("artist").count()
).count().toFloat()

// %%
countUniqueArtists2022
// Out:
// 2844.0

// %%
countUniqueArtists2023
// Out:
// 2953.0

// %%
countUniqueArtists2023 / countUniqueArtists2022
// Out:
// 1.0383263

// %%
val countTotalSongs2022 = dfWrapped2022.count().toFloat()

// %%
val countTotalSongs2023 = dfWrapped2023.count().toFloat()

// %%
countTotalSongs2022
// Out:
// 25351.0

// %%
countTotalSongs2023
// Out:
// 17852.0

// %%
countTotalSongs2023 / countTotalSongs2022
// Out:
// 0.7041931

// %%
%use lets-plot
// Out:
//    <div id="YDuDmq"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("YDuDmq").appendChild(div);
//            };
//            var e = document.getElementById("YDuDmq");
//            e.appendChild(script);
//        })();
//    </script>

// %%
val plotData2022 = 
    letsPlot(
        dfWrappedWithDate2022
            .sortBy("date")
            .toMap()
    ) { x = "date" } + ggsize(630, 500)
    
plotData2022 + geomHistogram(binWidth=0.5)
// Out:
//    <div id="95qxES"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"date"
// },
// "data":{
// },
// "ggsize":{
// "width":630.0,
// "height":500.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"bin",
// "position":"stack",
// "binwidth":0.5,
// "geom":"histogram",
// "data":{
// "date":["2022-01-01 ","2022-01-01 ","2022-01-02 ","2022-01-02 ","2022-01-03 ","2022-01-03 ","2022-01-05 ","2022-01-05 ","2022-01-07 ","2022-01-07 ","2022-01-08 ","2022-01-08 ","2022-01-11 ","2022-01-11 ","2022-01-14 ","2022-01-14 ","2022-01-15 ","2022-01-15 ","2022-01-16 ","2022-01-16 ","2022-01-17 ","2022-01-17 ","2022-01-18 ","2022-01-18 ","2022-01-19 ","2022-01-19 ","2022-01-20 ","2022-01-20 ","2022-01-21 ","2022-01-21 ","2022-01-22 ","2022-01-22 ","2022-01-23 ","2022-01-23 ","2022-01-24 ","2022-01-24 ","2022-01-25 ","2022-01-25 ","2022-01-26 ","2022-01-26 ","2022-01-27 ","2022-01-27 ","2022-01-28 ","2022-01-28 ","2022-01-29 ","2022-01-29 ","2022-01-30 ","2022-01-30 ","2022-01-31 ","2022-01-31 ","2022-02-01 ","2022-02-01 ","2022-02-03 ","2022-02-03 ","2022-02-04 ","2022-02-04 ","2022-02-05 ","2022-02-05 ","2022-02-06 ","2022-02-06 ","2022-02-07 ","2022-02-07 ","2022-02-08 ","2022-02-08 ","2022-02-09 ","2022-02-09 ","2022-02-10 ","2022-02-10 ","2022-02-11 ","2022-02-11 ","2022-02-12 ","2022-02-12 ","2022-02-13 ","2022-02-13 ","2022-02-15 ","2022-02-15 ","2022-02-16 ","2022-02-16 ","2022-02-17 ","2022-02-17 ","2022-02-18 ","2022-02-18 ","2022-02-19 ","2022-02-19 ","2022-02-20 ","2022-02-20 ","2022-02-21 ","2022-02-21 ","2022-02-22 ","2022-02-22 ","2022-02-23 ","2022-02-23 ","2022-02-24 ","2022-02-24 ","2022-02-25 ","2022-02-25 ","2022-02-26 ","2022-02-26 ","2022-02-27 ","2022-02-27 ","2022-02-28 ","2022-02-28 ","2022-03-01 ","2022-03-01 ","2022-03-02 ","2022-03-02 ","2022-03-04 ","2022-03-04 ","2022-03-05 ","2022-03-05 ","2022-03-06 ","2022-03-06 ","2022-03-07 ","2022-03-07 ","2022-03-08 ","2022-03-08 ","2022-03-09 ","2022-03-09 ","2022-03-10 ","2022-03-10 ","2022-03-11 ","2022-03-11 ","2022-03-12 ","2022-03-12 ","2022-03-13 ","2022-03-13 ","2022-03-14 ","2022-03-14 ","2022-03-15 ","2022-03-15 ","2022-03-16 ","2022-03-16 ","2022-03-17 ","2022-03-17 ","2022-03-18 ","2022-03-18 ","2022-03-19 ","2022-03-19 ","2022-03-20 ","2022-03-20 ","2022-03-21 ","2022-03-21 ","2022-03-22 ","2022-03-22 ","2022-03-23 ","2022-03-23 ","2022-03-24 ","2022-03-24 ","2022-03-25 ","2022-03-25 ","2022-03-26 ","2022-03-26 ","2022-03-27 ","2022-03-27 ","2022-03-28 ","2022-03-28 ","2022-03-29 ","2022-03-29 ","2022-03-30 ","2022-03-30 ","2022-03-31 ","2022-03-31 ","2022-04-02 ","2022-04-02 ","2022-04-03 ","2022-04-03 ","2022-04-04 ","2022-04-04 ","2022-04-05 ","2022-04-05 ","2022-04-06 ","2022-04-06 ","2022-04-07 ","2022-04-07 ","2022-04-08 ","2022-04-08 ","2022-04-11 ","2022-04-11 ","2022-04-12 ","2022-04-12 ","2022-04-13 ","2022-04-13 ","2022-04-14 ","2022-04-14 ","2022-04-15 ","2022-04-15 ","2022-04-16 ","2022-04-16 ","2022-04-17 ","2022-04-17 ","2022-04-18 ","2022-04-18 ","2022-04-19 ","2022-04-19 ","2022-04-21 ","2022-04-21 ","2022-04-22 ","2022-04-22 ","2022-04-23 ","2022-04-23 ","2022-04-24 ","2022-04-24 ","2022-04-26 ","2022-04-26 ","2022-04-27 ","2022-04-27 ","2022-04-28 ","2022-04-28 ","2022-04-29 ","2022-04-29 ","2022-04-30 ","2022-04-30 ","2022-05-01 ","2022-05-01 ","2022-05-02 ","2022-05-02 ","2022-05-04 ","2022-05-04 ","2022-05-05 ","2022-05-05 ","2022-05-06 ","2022-05-06 ","2022-05-07 ","2022-05-07 ","2022-05-08 ","2022-05-08 ","2022-05-09 ","2022-05-09 ","2022-05-10 ","2022-05-10 ","2022-05-11 ","2022-05-11 ","2022-05-13 ","2022-05-13 ","2022-05-14 ","2022-05-14 ","2022-05-15 ","2022-05-15 ","2022-05-16 ","2022-05-16 ","2022-05-17 ","2022-05-17 ","2022-05-18 ","2022-05-18 ","2022-05-19 ","2022-05-19 ","2022-05-20 ","2022-05-20 ","2022-05-21 ","2022-05-21 ","2022-05-22 ","2022-05-22 ","2022-05-23 ","2022-05-23 ","2022-05-24 ","2022-05-24 ","2022-05-25 ","2022-05-25 ","2022-05-26 ","2022-05-26 ","2022-05-27 ","2022-05-27 ","2022-05-28 ","2022-05-28 ","2022-05-29 ","2022-05-29 ","2022-05-30 ","2022-05-30 ","2022-05-31 ","2022-05-31 ","2022-06-01 ","2022-06-01 ","2022-06-02 ","2022-06-02 ","2022-06-03 ","2022-06-03 ","2022-06-04 ","2022-06-04 ","2022-06-05 ","2022-06-05 ","2022-06-06 ","2022-06-06 ","2022-06-07 ","2022-06-07 ","2022-06-08 ","2 ...
// "..count..":[50.0,0.0,61.0,0.0,64.0,0.0,95.0,0.0,16.0,0.0,1.0,0.0,21.0,0.0,71.0,0.0,2.0,0.0,1.0,0.0,57.0,0.0,121.0,0.0,202.0,0.0,178.0,0.0,186.0,0.0,111.0,0.0,12.0,0.0,118.0,0.0,70.0,0.0,25.0,0.0,220.0,0.0,235.0,0.0,76.0,0.0,230.0,0.0,238.0,0.0,193.0,0.0,51.0,0.0,154.0,0.0,65.0,0.0,47.0,0.0,95.0,0.0,56.0,0.0,142.0,0.0,122.0,0.0,103.0,0.0,116.0,0.0,184.0,0.0,9.0,0.0,120.0,0.0,36.0,0.0,19.0,0.0,1.0,0.0,6.0,0.0,71.0,0.0,30.0,0.0,29.0,0.0,43.0,0.0,4.0,0.0,21.0,0.0,12.0,0.0,127.0,0.0,138.0,0.0,25.0,0.0,47.0,0.0,7.0,0.0,75.0,0.0,17.0,0.0,33.0,0.0,36.0,0.0,57.0,0.0,38.0,0.0,72.0,0.0,60.0,0.0,130.0,0.0,220.0,0.0,9.0,0.0,105.0,0.0,120.0,

// %%
val plotData2023 = 
    letsPlot(
        dfWrappedWithDate2023
            .sortBy("date")
            .toMap()
    ) { x = "date" } + ggsize(630, 500)
    
plotData2023 + geomHistogram(binWidth=0.5)
// Out:
//    <div id="2Hnqqo"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"date"
// },
// "data":{
// },
// "ggsize":{
// "width":630.0,
// "height":500.0
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"bin",
// "position":"stack",
// "binwidth":0.5,
// "geom":"histogram",
// "data":{
// "date":["2023-01-01 ","2023-01-01 ","2023-01-02 ","2023-01-02 ","2023-01-03 ","2023-01-03 ","2023-01-04 ","2023-01-04 ","2023-01-05 ","2023-01-05 ","2023-01-06 ","2023-01-06 ","2023-01-07 ","2023-01-07 ","2023-01-08 ","2023-01-08 ","2023-01-09 ","2023-01-09 ","2023-01-10 ","2023-01-10 ","2023-01-11 ","2023-01-11 ","2023-01-12 ","2023-01-12 ","2023-01-13 ","2023-01-13 ","2023-01-14 ","2023-01-14 ","2023-01-15 ","2023-01-15 ","2023-01-16 ","2023-01-16 ","2023-01-17 ","2023-01-17 ","2023-01-18 ","2023-01-18 ","2023-01-19 ","2023-01-19 ","2023-01-20 ","2023-01-20 ","2023-01-21 ","2023-01-21 ","2023-01-22 ","2023-01-22 ","2023-01-23 ","2023-01-23 ","2023-01-24 ","2023-01-24 ","2023-01-25 ","2023-01-25 ","2023-01-26 ","2023-01-26 ","2023-01-27 ","2023-01-27 ","2023-01-29 ","2023-01-29 ","2023-01-30 ","2023-01-30 ","2023-01-31 ","2023-01-31 ","2023-02-01 ","2023-02-01 ","2023-02-03 ","2023-02-03 ","2023-02-06 ","2023-02-06 ","2023-02-07 ","2023-02-07 ","2023-02-08 ","2023-02-08 ","2023-02-09 ","2023-02-09 ","2023-02-10 ","2023-02-10 ","2023-02-11 ","2023-02-11 ","2023-02-12 ","2023-02-12 ","2023-02-13 ","2023-02-13 ","2023-02-14 ","2023-02-14 ","2023-02-15 ","2023-02-15 ","2023-02-16 ","2023-02-16 ","2023-02-17 ","2023-02-17 ","2023-02-18 ","2023-02-18 ","2023-02-20 ","2023-02-20 ","2023-02-22 ","2023-02-22 ","2023-02-23 ","2023-02-23 ","2023-02-24 ","2023-02-24 ","2023-02-25 ","2023-02-25 ","2023-02-26 ","2023-02-26 ","2023-02-27 ","2023-02-27 ","2023-02-28 ","2023-02-28 ","2023-03-01 ","2023-03-01 ","2023-03-02 ","2023-03-02 ","2023-03-03 ","2023-03-03 ","2023-03-04 ","2023-03-04 ","2023-03-05 ","2023-03-05 ","2023-03-06 ","2023-03-06 ","2023-03-07 ","2023-03-07 ","2023-03-09 ","2023-03-09 ","2023-03-10 ","2023-03-10 ","2023-03-11 ","2023-03-11 ","2023-03-12 ","2023-03-12 ","2023-03-13 ","2023-03-13 ","2023-03-14 ","2023-03-14 ","2023-03-15 ","2023-03-15 ","2023-03-16 ","2023-03-16 ","2023-03-17 ","2023-03-17 ","2023-03-18 ","2023-03-18 ","2023-03-19 ","2023-03-19 ","2023-03-20 ","2023-03-20 ","2023-03-21 ","2023-03-21 ","2023-03-22 ","2023-03-22 ","2023-03-23 ","2023-03-23 ","2023-03-24 ","2023-03-24 ","2023-03-25 ","2023-03-25 ","2023-03-26 ","2023-03-26 ","2023-03-27 ","2023-03-27 ","2023-03-28 ","2023-03-28 ","2023-03-29 ","2023-03-29 ","2023-03-30 ","2023-03-30 ","2023-03-31 ","2023-03-31 ","2023-04-01 ","2023-04-01 ","2023-04-02 ","2023-04-02 ","2023-04-03 ","2023-04-03 ","2023-04-04 ","2023-04-04 ","2023-04-05 ","2023-04-05 ","2023-04-06 ","2023-04-06 ","2023-04-08 ","2023-04-08 ","2023-04-09 ","2023-04-09 ","2023-04-11 ","2023-04-11 ","2023-04-12 ","2023-04-12 ","2023-04-13 ","2023-04-13 ","2023-04-14 ","2023-04-14 ","2023-04-15 ","2023-04-15 ","2023-04-17 ","2023-04-17 ","2023-04-20 ","2023-04-20 ","2023-04-21 ","2023-04-21 ","2023-04-23 ","2023-04-23 ","2023-04-24 ","2023-04-24 ","2023-04-25 ","2023-04-25 ","2023-04-27 ","2023-04-27 ","2023-04-28 ","2023-04-28 ","2023-05-01 ","2023-05-01 ","2023-05-03 ","2023-05-03 ","2023-05-04 ","2023-05-04 ","2023-05-05 ","2023-05-05 ","2023-05-06 ","2023-05-06 ","2023-05-07 ","2023-05-07 ","2023-05-08 ","2023-05-08 ","2023-05-09 ","2023-05-09 ","2023-05-10 ","2023-05-10 ","2023-05-11 ","2023-05-11 ","2023-05-12 ","2023-05-12 ","2023-05-13 ","2023-05-13 ","2023-05-14 ","2023-05-14 ","2023-05-15 ","2023-05-15 ","2023-05-16 ","2023-05-16 ","2023-05-17 ","2023-05-17 ","2023-05-18 ","2023-05-18 ","2023-05-19 ","2023-05-19 ","2023-05-21 ","2023-05-21 ","2023-05-22 ","2023-05-22 ","2023-05-23 ","2023-05-23 ","2023-05-24 ","2023-05-24 ","2023-05-25 ","2023-05-25 ","2023-05-27 ","2023-05-27 ","2023-05-28 ","2023-05-28 ","2023-05-29 ","2023-05-29 ","2023-05-30 ","2023-05-30 ","2023-05-31 ","2023-05-31 ","2023-06-01 ","2023-06-01 ","2023-06-05 ","2023-06-05 ","2023-06-06 ","2023-06-06 ","2023-06-07 ","2023-06-07 ","2023-06-08 ","2023-06-08 ","2023-06-09 ","2023-06-09 ","2023-06-12 ","2023-06-12 ","2023-06-13 ","2023-06-13 ","2023-06-14 ","2023-06-14 ","2023-06-15 ","2023-06-15 ","2023-06-16 ","2 ...
// "..count..":[21.0,0.0,20.0,0.0,9.0,0.0,12.0,0.0,1.0,0.0,43.0,0.0,64.0,0.0,3.0,0.0,15.0,0.0,99.0,0.0,48.0,0.0,29.0,0.0,7.0,0.0,18.0,0.0,8.0,0.0,81.0,0.0,4.0,0.0,25.0,0.0,103.0,0.0,37.0,0.0,43.0,0.0,8.0,0.0,28.0,0.0,95.0,0.0,103.0,0.0,135.0,0.0,36.0,0.0,9.0,0.0,31.0,0.0,40.0,0.0,103.0,0.0,55.0,0.0,64.0,0.0,75.0,0.0,166.0,0.0,92.0,0.0,91.0,0.0,46.0,0.0,69.0,0.0,129.0,0.0,54.0,0.0,80.0,0.0,94.0,0.0,21.0,0.0,21.0,0.0,26.0,0.0,31.0,0.0,107.0,0.0,54.0,0.0,12.0,0.0,4.0,0.0,46.0,0.0,60.0,0.0,97.0,0.0,90.0,0.0,108.0,0.0,77.0,0.0,120.0,0.0,80.0,0.0,50.0,0.0,51.0,0.0,125.0,0.0,78.0,0.0,99.0,0.0,119.0,0.0,64.0,0.0,114.0,0.0,65.0,0.0,34.0,0.0
